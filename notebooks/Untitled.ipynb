# %%
import pandas as pd
fle='C:\gavia\Erebus-Trials\Speed (knots)-data-2023-08-02 16_23_12.csv'

# %%
df=pd.read_csv(fle, index_col='Time')
df
# Out:
#                      speedknots
# Time
# 2023-08-02 11:23:02         0.3
# 2023-08-02 11:23:03         0.3
# 2023-08-02 11:23:03         0.3
# 2023-08-02 11:23:04         0.3
# 2023-08-02 11:23:04         0.3
# ...                         ...
# 2023-08-02 17:23:00         0.1
# 2023-08-02 17:23:00         0.1
# 2023-08-02 17:23:01         0.1
# 2023-08-02 17:23:01         0.1
# 2023-08-02 17:23:02         0.1
#
# [43200 rows x 1 columns]

# %%
df.speedknots.plot(marker="*",figsize=(20, 10),linestyle="None" )
# Out:
# <Axes: xlabel='Time'>
