# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
drive='e:'
campaign='SDA-trials-2023'


# AUV log files read and get DF
folder = 'files'
subfolder='log'
subfolder='processed-log-data'
auvfile=os.path.join(drive,campaign,folder,subfolder,'auvdata.csv')
auv=pd.read_csv(auvfile)

# USBL log files read and get DF
folder='USBL'
subfolder='data'
usblfile=os.path.join(drive,campaign,folder,subfolder,'USBL-ObsLatLong.csv')
usbl=pd.read_csv(usblfile)
# Out:
# C:\Users\sa01ld\AppData\Local\Temp\ipykernel_21136\1912608817.py:10: DtypeWarning: Columns (35,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   auv=pd.read_csv(auvfile)

# %%
auv["time-nav"]=pd.to_datetime(auv["time-nav"])

# %%
mask = (auv['time-nav'] > '2023 08 01') & (auv['time-nav'] <= '2023 08 04')
gauv=auv.loc[mask]

# %%
## plot USBL vs. AUV lat Lon

x=usbl.Lon.where(usbl.Address=='2207')
y=usbl.Lat.where(usbl.Address=='2207')



X=gauv.Lon
Y=gauv.Lat

plt.scatter(X,Y,
            c='blue', 
            marker='.',
            s=10,
            label='AUV DR',
            alpha=0.3, edgecolors='none')
plt.scatter(x,y,
            c='deeppink', 
            marker='.',
            s=50,
            label='Nano 2207',
            alpha=0.9, edgecolors='none')

plt.title('Erebus Trials, Gairloch AUV missions')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend()
plt.grid(True)

plt.savefig(os.path.join(drive,campaign,'figures','AUVvsUSBL.png'))

# %%
## plot 
auv.plot(kind='scatter',
        x='Lon',
        y='Lat',
        s=5,
        c='altitude',
        colormap='plasma')
plt.title('Erebus Trials, Gairloch AUV missions')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.savefig(os.path.join(drive,campaign,'figures','AUValtitude.png'))

# %%
X=auv.salinity
Y=auv.temperature_x
z=auv.pressure
auv.plot(kind='scatter',
            x='salinity',
            y='temperature_x',
            s=5,
            c='pressure',
            colormap='viridis')
plt.xlim([33, 35])
plt.title('Erebus Trials, AUV missions')
plt.xlabel('Salinity (PSU)')
plt.ylabel('Temperature (degC)')
plt.legend()
plt.grid(True)
plt.savefig(os.path.join(drive,campaign,'figures','AUVTS.png'))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
X=auv.salinity
Y=auv.temperature_x
z=auv.pressure
auv.plot(kind='scatter',
            x='salinity',
            y='o2-concentration',
            s=5,
            c='pressure',
            colormap='viridis')
plt.xlim([34.4, 34.8])
plt.title('Erebus Trials, AUV missions')
plt.xlabel('Salinity (PSU)')
plt.ylabel('Oxygen concentration')
plt.legend()
plt.grid(True)
plt.savefig(os.path.join(drive,campaign,'figures','AUVo2.png'))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
auv["o2-concentration"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 36018   NaN
# 36019   NaN
# 36020   NaN
# 36021   NaN
# 36022   NaN
# Name: o2-concentration, Length: 36023, dtype: float64

# %%
list(auv)
# Out:
# ['Unnamed: 0',
#  'timestamp',
#  'time-nav',
#  'temperature-nav',
#  'dead-reckoning-position',
#  'dead-reckoning-variance',
#  'altitude',
#  'dead-reckoning-distance',
#  'DRHeading',
#  'DRVelocity',
#  'DRPitch',
#  'DRRoll',
#  'DRLat',
#  'DRLon',
#  'speed',
#  'Heading',
#  'Pitch',
#  'Roll',
#  'Depth',
#  'Lat',
#  'Lon',
#  'salinity-nav',
#  'water-density',
#  'time_x',
#  'UTC',
#  'lat',
#  'lon',
#  'quality',
#  'hdop',
#  'time_y',
#  'conductivity',
#  'pressure',
#  'salinity',
#  'sound-velocity',
#  'temperature_x',
#  'time',
#  'air-saturation',
#  'c1-amp',
#  'c1-r-ph',
#  'c2-amp',
#  'c2-r-ph',
#  'cal-phase',
#  'o2-concentration',
#  'product-number',
#  'raw-temp',
#  'serial-number',
#  't-c-phase',
#  'temperature_y']
