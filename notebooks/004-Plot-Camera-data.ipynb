# %%
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# %%
indir = os.path.join('e:','ECOWind-accelerate','image-metadata')

# %%
project='ECOWind-accelerate'
drive ='e:'
filename = os.path.join(drive,project,'image-metadata','photo-coords.csv')
df=pd.read_csv(filename)
fig,ax = plt.subplots(figsize=[4,4])
alt = df["altitude"]
pit = df["pitch"]
ax.plot(pit,alt,'.',color='dimgray')
ax.plot([-20,20],[1.8,1.8],label='desired altitude')
ax.set_xlim(-20, 20)
ax.set_ylim(1, 4)
ax.set_xlabel('Pitch')
ax.set_ylabel('Altitude')
plt.legend()
plt.grid()
plt.savefig(os.path.join(drive,project,'alt-pitch.png'),dpi=150)

# %%
project='Mulroy-Bay'
drive ='e:'
filename=os.path.join(drive,project,'image-metadata','photo-coords.csv')
df=pd.read_csv(filename)

fig,(ax1,ax2) = plt.subplots(1,2,figsize=[8,4])
alt = df["altitude"]
pit = df["pitch"]
ax1.plot(pit,alt,'.k')
ax1.set_ylim(1, 4)
ax1.set_xlim(-30, 30)
ax1.set_xlabel('Pitch')
ax1.set_ylabel('Altitude')


project='ECOWind-accelerate'
drive ='e:'
filename = os.path.join(drive,project,'image-metadata','photo-coords.csv')
df=pd.read_csv(filename)
alt = df["altitude"]
pit = df["pitch"]
ax2.plot(pit,alt,'.k')
ax2.set_ylim(1, 4)
ax2.set_xlim(-30, 30)
ax2.set_xlabel('Pitch')
ax2.set_ylabel('Altitude')
# Out:
# Text(0, 0.5, 'Altitude')
